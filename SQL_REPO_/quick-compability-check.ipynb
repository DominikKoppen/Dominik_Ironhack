# %%
import pandas as pd

bechdel = pd.read_csv(r"D:\ANALYTICS\Jupyter Notebook\Jupyter Notebook Files\IRONHACK\FULL_COURSE\GitHubRepos (Win)\Seblab_Ironhack\Projects\W03 Bechdel (SQL project)\imdb_movies.csv")
imdb = pd.read_csv(r"D:\ANALYTICS\Jupyter Notebook\Jupyter Notebook Files\IRONHACK\FULL_COURSE\GitHubRepos (Win)\Seblab_Ironhack\Projects\W03 Bechdel (SQL project)\bechdel_movies_2023_FEB.csv")

# %%
bechdel.head(2)
# Out:
#                       names       date_x  score  \
# 0                 Creed III  03/02/2023    73.0
# 1  Avatar: The Way of Water  12/15/2022    78.0
#
#                                 genre  \
# 0                       Drama, Action
# 1  Science Fiction, Adventure, Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
#
#                                                 crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
#
#                  orig_title     status orig_lang     budget_x       revenue  \
# 0                 Creed III   Released   English   75000000.0  2.716167e+08
# 1  Avatar: The Way of Water   Released   English  460000000.0  2.316795e+09
#
#   country
# 0      AU
# 1      AU

# %%
imdb.head(2)
# Out:
#                title  year  rating  dubious    imdbid    id  submitterid  \
# 0   Passage de Venus  1874       0      0.0   3155794  9602        18880
# 1  La Rosace Magique  1877       0      0.0  14495706  9804        19145
#
#                date  visible
# 0  2021-04-02 20:58        1
# 1   2021-05-11 0:11        1

# %%
bechdel = bechdel.rename(columns= {'names': 'title'})
bechdel.head(2)
# Out:
#                       title       date_x  score  \
# 0                 Creed III  03/02/2023    73.0
# 1  Avatar: The Way of Water  12/15/2022    78.0
#
#                                 genre  \
# 0                       Drama, Action
# 1  Science Fiction, Adventure, Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
#
#                                                 crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
#
#                  orig_title     status orig_lang     budget_x       revenue  \
# 0                 Creed III   Released   English   75000000.0  2.716167e+08
# 1  Avatar: The Way of Water   Released   English  460000000.0  2.316795e+09
#
#   country
# 0      AU
# 1      AU

# %%
bechdel.shape
# Out:
# (10178, 12)

# %%
imdb.shape
# Out:
# (9902, 9)

# %%
merged = pd.merge(bechdel, imdb, on='title')
merged.shape
merged.head(5)
# Out:
#                                title       date_x  score  \
# 0                       Cocaine Bear  02/23/2023    66.0
# 1       Puss in Boots: The Last Wish  12/26/2022    83.0
# 2     Black Panther: Wakanda Forever  11/10/2022    73.0
# 3  Ant-Man and the Wasp: Quantumania  02/16/2023    63.0
# 4               John Wick: Chapter 2  05/18/2017    73.0
#
#                                            genre  \
# 0                        Thriller, Comedy, Crime
# 1  Animation, Family, Fantasy, Adventure, Comedy
# 2             Action, Adventure, Science Fiction
# 3             Science Fiction, Adventure, Action
# 4                        Action, Thriller, Crime
#
#                                             overview  \
# 0  Inspired by a true story, an oddball group of ...
# 1  Puss in Boots discovers that his passion for a...
# 2  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...
# 3  Super-Hero partners Scott Lang and Hope van Dy...
# ...
