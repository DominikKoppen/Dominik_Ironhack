# %%
import pandas as pd

# %%
data = pd.read_csv('coffee_analysis.csv')

# %%
data
# Out:
#                             name                    roaster         roast  \
# 0        “Sweety” Espresso Blend                     A.R.C.  Medium-Light
# 1           Flora Blend Espresso                     A.R.C.  Medium-Light
# 2       Ethiopia Shakiso Mormora               Revel Coffee  Medium-Light
# 3             Ethiopia Suke Quto                Roast House  Medium-Light
# 4     Ethiopia Gedeb Halo Beriti  Big Creek Coffee Roasters        Medium
# ...                          ...                        ...           ...
# 2090              Finca Patzibir               El Gran Cafe  Medium-Light
# 2091             Proyecto Aurora               El Gran Cafe  Medium-Light
# 2092            Finca El Potrero               El Gran Cafe  Medium-Light
# 2093    Chacayá Santiago Atitlán               El Gran Cafe  Medium-Light
# 2094              Espresso No. 3               El Gran Cafe  Medium-Light
#
#         loc_country                     origin_1           origin_2  100g_USD  \
# ...

# %%
data1 = pd.read_csv('simplified_coffee.csv')

# %%
data1
# Out:
#                                   name                     roaster  \
# 0             Ethiopia Shakiso Mormora                Revel Coffee
# 1                   Ethiopia Suke Quto                 Roast House
# 2           Ethiopia Gedeb Halo Beriti   Big Creek Coffee Roasters
# 3              Ethiopia Kayon Mountain  Red Rooster Coffee Roaster
# 4     Ethiopia Gelgelu Natural Organic   Willoughby's Coffee & Tea
# ...                                ...                         ...
# 1241                    Finca Patzibir                El Gran Cafe
# 1242                   Proyecto Aurora                El Gran Cafe
# 1243                  Finca El Potrero                El Gran Cafe
# 1244          Chacayá Santiago Atitlán                El Gran Cafe
# 1245                    Espresso No. 3                El Gran Cafe
#
#              roast    loc_country     origin  100g_USD  rating    review_date  \
# 0     Medium-Light  United States   Ethiopia      4.70      92  November 2017
# ...

# %%
data2 = pd.read_csv('coffee_analysis_clean.csv')

# %%
data2
# Out:
#                             name                    roaster         roast  \
# 0        “Sweety” Espresso Blend                     A.R.C.  Medium-Light
# 1           Flora Blend Espresso                     A.R.C.  Medium-Light
# 2       Ethiopia Shakiso Mormora               Revel Coffee  Medium-Light
# 3             Ethiopia Suke Quto                Roast House  Medium-Light
# 4     Ethiopia Gedeb Halo Beriti  Big Creek Coffee Roasters        Medium
# ...                          ...                        ...           ...
# 2128              Finca Patzibir               El Gran Cafe  Medium-Light
# 2129             Proyecto Aurora               El Gran Cafe  Medium-Light
# 2130            Finca El Potrero               El Gran Cafe  Medium-Light
# 2131    Chacayá Santiago Atitlán               El Gran Cafe  Medium-Light
# 2132              Espresso No. 3               El Gran Cafe  Medium-Light
#
#         loc_country                     origin_1           origin_2  100g_USD  \
# ...

# %%
data3 = pd.read_csv('cost-of-living.csv')

# %%
data3
# Out:
#       Unnamed: 0                city      country     x1     x2     x3     x4  \
# 0              0               Delhi        India   4.90  22.04   4.28   1.84
# 1              1            Shanghai        China   5.59  40.51   5.59   1.12
# 2              2             Jakarta    Indonesia   2.54  22.25   3.50   2.02
# 3              3              Manila  Philippines   3.54  27.40   3.54   1.24
# 4              4               Seoul  South Korea   7.16  52.77   6.03   3.02
# ...          ...                 ...          ...    ...    ...    ...    ...
# 4869        4869        Peterborough    Australia    NaN    NaN    NaN    NaN
# 4870        4870          Georgetown    Australia    NaN    NaN    NaN    NaN
# 4871        4871  Ixtapa Zihuatanejo       Mexico   5.19  31.13  12.97   0.99
# 4872        4872             Iqaluit       Canada  29.78  74.61  13.77   6.70
# 4873        4873              Neiafu        Tonga    NaN  29.53  10.55  10.55
#
# ...

# %%
data3.columns
# Out:
# Index(['Unnamed: 0', 'city', 'country', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6',
#        'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16',
#        'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26',
#        'x27', 'x28', 'x29', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36',
#        'x37', 'x38', 'x39', 'x40', 'x41', 'x42', 'x43', 'x44', 'x45', 'x46',
#        'x47', 'x48', 'x49', 'x50', 'x51', 'x52', 'x53', 'x54', 'x55',
#        'data_quality'],
#       dtype='object')
