# %%
import cv2
from tkinter import image_names
import os 
import matplotlib.pyplot as plt
import time
from PIL import Image
from hashlib import md5

# %%
#cv2.namedWindow("Screenshot_App")

# %%
def get_file_hash(file_path):
    """Generate a hash for a given file."""
    with open(file_path, 'rb') as f:
        return md5(f.read()).hexdigest()

def detect_new_picture(folder_path, checked_files=set()):
    """Detect if a new picture has been uploaded in the specified folder."""
    new_files = set()

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)

        # Skip directories
        if os.path.isdir(file_path):
            continue

        # Check if the file has already been checked
        if filename in checked_files:
            continue

        # Get the hash of the current file
        current_hash = get_file_hash(file_path)

        # Add the current file to the set of checked files
        checked_files.add(filename)

        # Check if the file is new (not in the set of checked hashes)
        if current_hash not in checked_files:
            new_files.add(filename)

    return new_files

def main():
    cam = cv2.VideoCapture(1)
    img_counter = 0

    folder_path = '/Users/dominik/Documents/GitHub/Dominik_Ironhack/Projects/Final_Project'
    checked_files = set()

    while True:
        ret, frame = cam.read()

        if not ret:
            print("ERROR")
            break

        cv2.imshow("Frame", frame)

        k = cv2.waitKey(1)

        if k == 27:   # 27 is esc key
            print("EXIT")
            break

        elif k == 32:  # 32 is space bar
            img1 = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            plt.imshow(img1)
            plt.title("Camera image 1")
            img_name = "opencv_frame_{}.png".format(time.time())
            cv2.imwrite(img_name, frame)
            print("Screenshot taken")
            img_counter += 1

        # Integrate the function to detect new pictures
        new_files = detect_new_picture(folder_path, checked_files)

        # Process new files as needed
        for new_file in new_files:
            print(f"New picture detected: {new_file}")

    # Release resources
    cam.release()
    cv2.destroyAllWindows()
    cv2.waitKey(0)

if __name__ == "__main__":
    main()
# Out:
# New picture detected: opencv_frame_1702373530.9129338.png
# New picture detected: opencv_frame_1702386649.583081.jpg
# New picture detected: opencv_frame_1702375382.3951948.png
# New picture detected: opencv_frame_1702542982.7651289.jpg
# New picture detected: opencv_frame_1702375004.530085.png
# New picture detected: opencv_frame_1702373716.069397.png
# New picture detected: opencv_frame_1702375005.6765928.png
# New picture detected: frame_4.png
# New picture detected: opencv_frame_1702373514.3649468.png
# New picture detected: frame_2.png
# New picture detected: opencv_frame_1702542982.9916139.jpg
# New picture detected: opencv_frame_1702379981.744836.jpg
# New picture detected: opencv_frame_1702377998.3085902.jpg
# New picture detected: Final.ipynb
# New picture detected: opencv_frame_1702542981.911084.jpg
# New picture detected: opencv_frame_1702373757.094614.png
# New picture detected: opencv_frame_1702378666.3457549.jpg
# New picture detected: frame_1.png
# New picture detected: opencv_frame_1702373996.207521.png
# New picture detected: opencv_frame_1702545282.654971.jpg
# New picture detected: opencv_frame_1702378663.180015.jpg
# New picture detected: frame_3.png
# New picture detected: opencv_frame_1702562457.356779.jpg
# New picture detected: opencv_frame_1702377999.4419131.jpg
# New picture detected: opencv_frame_1702376293.7786748.jpg
# New picture detected: opencv_frame_1702381181.729279.jpg
# New picture detected: opencv_frame_1702378496.8545978.jpg
# New picture detected: opencv_frame_1702377826.708298.jpg
# New picture detected: experimenting with images still a lot more.ipynb
# New picture detected: opencv_frame_1702375567.502437.jpg
# New picture detected: opencv_frame_1702377763.817232.jpg
# New picture detected: opencv_frame_1702545284.202032.jpg
# New picture detected: opencv_frame_1702545285.5599701.png
# New picture detected: opencv_frame_1702378668.122848.jpg
# New picture detected: opencv_frame_1702379857.172108.jpg
# New picture detected: opencv_frame_1702573767.690131.jpg
# New picture detected: opencv_frame_1702379956.022756.jpg
# New picture detected: opencv_frame_1702542982.584807.jpg
# New picture detected: opencv_frame_1702373500.012724.png
# New picture detected: Webcam.ipynb
# New picture detected: frame_0.png
# New picture detected: .DS_Store
# EXIT
